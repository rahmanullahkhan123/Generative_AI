# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanullahkhan123/Generative_AI/blob/main/AI_Software_Development_Agent_(AutoCoder).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

if torch.cuda.is_available():
    print("✅ GPU is enabled.")
    print("Device:", torch.cuda.get_device_name(0))
else:
    print("❌ GPU is NOT enabled.")
    print("Go to Runtime → Change runtime type → Hardware accelerator → GPU")
# Out:
# ❌ GPU is NOT enabled.
# Go to Runtime → Change runtime type → Hardware accelerator → GPU

# %%
# !pip install -q transformers accelerate

# %%
# !pip install -q langchain
# !pip install -q langchain-community
# !pip install -q langchain-openai
# !pip install -q gradio
# !pip install -q chromadb
# !pip install -q faiss-cpu
# !pip install -q gitpython
# !pip install -q tiktoken
# !pip install -U langchain langchain-core langchain-community langchain-ollama

# %%
import os
import gradio as gr

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import ChatOllama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="deepseek-r1"
)

# %%
from transformers import pipeline

coder = pipeline(
    "text-generation",
    model="deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B",
    device_map="auto"
)
# Out:
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]

# %%
prompt = ChatPromptTemplate.from_template("""
You are an expert software engineer.

Task:
{question}

Generate professional quality code.
Explain everything clearly.
""")

# %%
def generate_code(question):

    result = coder(
        question,
        max_new_tokens=300
    )

    return result[0]["generated_text"]

# %%
print(generate_code(
"Create a Snake Game in Python"))
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=300) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Create a Snake Game in Python.
# ...

# %%
def debug_code(error):

    prompt = f"""
You are a Python debugger.

Explain this error.

{error}

Give corrected code.
"""

    answer = llm.invoke(prompt)

    return answer.content

# %%
def review_code(code):

    prompt = f"""
Review this code.

Find

- Bugs
- Security
- Performance
- Improvements

Code

{code}
"""

    result = llm.invoke(prompt)

    return result.content

# %%
def generate_readme(project):

    prompt = f"""
Write a professional README.

Project

{project}
"""

    answer = llm.invoke(prompt)

    return answer.content

# %%
with gr.Blocks() as demo:

    gr.Markdown("# AI Software Development Agent")

    prompt_box = gr.Textbox(
        lines=6,
        label="Enter your request"
    )

    output = gr.Textbox(
        lines=20,
        label="Result"
    )

    btn = gr.Button("Generate")

    btn.click(
        generate_code,
        inputs=prompt_box,
        outputs=output
    )

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a8cd92353033d51010.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a8cd92353033d51010.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
